# %% [markdown]
# Q1 . Create a navigation bar similar to the below-mentioned image. The navigation bar must contain 5
# navigation links that are properly placed within the navigation bar using the CSS box model. The navigation
# items must change their text color on hover.
#
# ```
# # This is formatted as code
# ```

# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>NAVIGATION BAR</title>
  <style>
     /* Reset default styles */
    body {
      font-family: Arial, Helvetica, sans-serif;
    }

 .navbar {
      background-color: #1c1a1a;
      color: rgb(255, 255, 255);
      padding: 10px 20px;
    }

.contanier{
  display: flex;
  justify-content: space-between;
  align-items: center;
}

.logo {
font: size 25px;
font-weight: 950px;
text-decoration: none;
color: white;
}

.nav-links {
  list-style-type: none;
  display: flex;
  gap: 30px;
  transition: all 0.3 ease;
}

.nav-links li {
  display: inline;
}

.nav-links a {
  text-decoration: none;
  color: white;
}

/* Hover effect */
.nav-links a:hover {
  color: #10dffb;
  transition-duration: 0s5s;
  transition-property: color;
  transition-timing-function: ease-in-out;

}

/* Search box styling */
.search-box {
  display: flex;
  gap: 5px;
}

  </style>
</head>
<body>
  <nav class="navbar">
    <div class="contanier">
      <a herf="#" class="logo">Logo</a>
      <ul class="nav-links">
        <li><a href="#">Home</a></li>
        <li><a href="#">About</a></li>
        <li><a href="#">Services</a></li>
        <li><a href="#">Contact</a></li>
      </ul>
      <div class="search-box">
        <input type="text" placeholder="Search...">
        <button type="submit">Search</button>
      </div>
    </div>
  </nav>
</body>
</html>

# %% [markdown]
# Q2. Create a div centered with an image and paragraph similar to the image mentioned below.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title> image tag </title>
</head>
<style>
  img{
    position:center;
  }
  .container {
    text-align: center;
    margin-top: 50px;
  }
  body {
    background-color: #f0f0f0;
    font-family: Arial, sans-serif;
  }
  img {
    margin-top: 90px;
    width: 300px;
    height: 200px;
    padding: 10px;
    border-radius: 10px;
    box-shadow: 0 4px 8px rgba(0, 0, 0, 0.2);
    transition: transform 0.2s;
  }
  p {
    font-size: 18px;
    color: #333;
    margin-top: 20px;
  }
  img:hover {
    transform: scale(1.05);
  }
  img:active {
    transform: scale(0.95);
  }
  p:hover {
    color: #ff0000;
  }
</style>
<body>
  <div class="container">
    <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTbnFMFz_PC5XKL47zTI-alZTld2w5atgRkuQ&s" alt=" Image" width="300" height="200">
  <p> this is a paragraph.
   A paragraph is a block of text that is separated from other blocks of text by a blank line.
  </p>
  </div>
</body>
</html>

# %% [markdown]
# Q3. Create a navigation bar similar to question 1. For each navigation item, use a different border style

# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>NAVIGATION BAR</title>
  <style>
     /* Reset default styles */
    body {
      font-family: Arial, Helvetica, sans-serif;
    }

 .navbar {
      background-color: #1c1a1a;
      color: rgb(255, 255, 255);
      padding: 10px 20px;
    }

.contanier{
  display: flex;
  justify-content: space-between;
  align-items: center;
}

.logo {
font: size 25px;
font-weight: 950px;
text-decoration: none;
color: white;
}

.nav-links {
  list-style-type: none;
  display: flex;
  gap: 25px;
  transition: all 0.3 ease;
}

.nav-links li {
  display: inline;
}

.nav-links a {
  text-decoration: none;
  color: white;
}

/* Hover effect */
.nav-links a:hover {
  color: #10dffb;
  transition-duration: 0s5s;
  transition-property: color;
  transition-timing-function: ease-in-out;

}

/* Search box styling */
.search-box {
  display: flex;
  gap: 5px;
}

.search-box input[type="text"] {
  border: 2px solid #26ff00; /* Solid */
}



  </style>
</head>
<body>
  <nav class="navbar">
    <div class="contanier">
      <a herf="#" class="logo">Logo</a>
      <ul class="nav-links">
        <li><a style="border:3px dotted #10dffb"href="#">Home</a></li>

        <li><a style="border:3px double #fb1010" href="#">About</a></li>

        <li><a style="border:3px dashed #10fb3f" href="#">Services</a></li>

        <li><a href="#">Contact</a></li>

      </ul>
      <div class="search-box">
        <input type="text" placeholder="Search...">
        <button type="submit">Search</button>
      </div>
    </div>
  </nav>
</body>
</html>

# %% [markdown]
# Q4  Create a simple webpage with an image and make the image circular using border-radius

# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title> image tag </title>
</head>
<style>
  img{
    position:center;
  }
  .container {
    text-align: center;
    margin-top: 50px;
  }
  body {
    background-color: #ffffff;
    font-family: Arial, sans-serif;
  }
  img {
    margin-top: 90px;
    width: 300px;
    height: 300px;
    padding: 10px;
    border-radius: 10000px;
    box-shadow: 0 4px 8px rgba(0, 0, 0, 0.700);
    transition: transform 0.2s;
  }
  p {
    font-size: 18px;
    color: #030303;
    margin-top: 20px;
  }
  img:hover {
    transform: scale(1.10);
  }
  img:active {
    transform: scale(0.95);
  }
  p:hover {
    color: #ff0000;
  }
</style>
<body>
  <div class="container">
    <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcTbnFMFz_PC5XKL47zTI-alZTld2w5atgRkuQ&s" alt=" Image" width="300" height="300">
     <p>This is a circular image</p>
  </div>
</body>
</html>

# %% [markdown]
# Q5. Create a simple blog website about Google fonts. The webpage must have the heading with “Oswald” font
# align center to the page, below the heading have an image of Google fonts and a paragraph about Google
# fonts in font “Montserrat” paragraph font style should be“montserrat” font&

# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Document</title>


<!-- Link to Google Fonts -->
<link href="https://fonts.googleapis.com/css2?family=Montserrat&family=Oswald&display=swap" rel="stylesheet">

<style>
    body {
        font-family: 'Montserrat', sans-serif;
        text-align: center;
        padding: 20px;
        background-color: #f9f9f9;
    }

    h1 {
        font-family: 'Oswald', sans-serif;
        font-size: 3em;
        margin-bottom: 20px;
    }

    img {
      box-shadow: #333 0px 0px 20px 0px;
        margin: 20px auto;
        border: 5px solid #caefff;
        max-width: 100%;
        height: auto;
        border-radius: 20px;
    }

    p {
        font-size: 1.2em;
        max-width: 700px;
        margin: 20px auto;
        line-height: 1.6;
        color: #333;
    }
</style>
</head>
<body>

  <h1>Google Fonts</h1>

  <!-- Example image (you can replace this URL with another if you want) -->
  <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQwW_1r_5mSNt1EZF2PgzlL7w4_y1AxPJY3GA&s" alt="Google Fonts Logo">

  <p>
      Google Fonts is a library of over a thousand free and open-source font families,
      making it easy for developers and designers to incorporate beautiful typography
      into their web projects. With fonts like Montserrat and Oswald, it's never been
      easier to create visually appealing websites with a touch of personal style.
  </p>

</body>
</html>

# %% [markdown]
# Q7. Create a simple webpage with a card similar to question number 2. The card must be semi-transparent as
# default and on hovering the card must be displayed clearly. Use CSS opacity to achieve this output.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Document</title>


<!-- Link to Google Fonts -->
<link href="https://fonts.googleapis.com/css2?family=Montserrat&family=Oswald&display=swap" rel="stylesheet">

<style>
    body {
        font-family: 'Montserrat', sans-serif;
        text-align: center;
        padding: 20px;
        background-color: #f9f9f9;
    }

    h1 {
        font-family: 'Oswald', sans-serif;
        font-size: 3em;
        margin-bottom: 20px;
    }

    img {
      box-shadow: #333 0px 0px 20px 0px;
        margin: 20px auto;
        border: 5px solid #caefff;
        max-width: 100%;
        height: auto;
        border-radius: 20px;
    }
img:hover {
        transform: scale(1.15);
        transition: transform 0.3s ease;
    }
    img {
    opacity: 0.5; /* Start transparent */
    transition: opacity 0.5s ease-in-out; /* Smooth transition */
}

img:hover {
    opacity: 1; /* Fully visible on hover */
}

    p {
        font-size: 1.2em;
        max-width: 700px;
        margin: 20px auto;
        line-height: 1.6;
        color: #333;
    }
</style>
</head>
<body>

  <h1>Google Fonts</h1>

  <!-- Example image (you can replace this URL with another if you want) -->
  <img src="https://encrypted-tbn0.gstatic.com/images?q=tbn:ANd9GcQwW_1r_5mSNt1EZF2PgzlL7w4_y1AxPJY3GA&s" alt="Google Fonts Logo">

  <p>
      Google Fonts is a library of over a thousand free and open-source font families,
      making it easy for developers and designers to incorporate beautiful typography
      into their web projects. With fonts like Montserrat and Oswald, it's never been
      easier to create visually appealing websites with a touch of personal style.
  </p>

</body>
</html>

# %% [markdown]
# Q8 . Create a simple list of items as mentioned in the below image.

# %%
<!DOCTYPE html>
<html lang="en">
<head>
  <meta charset="UTF-8">
  <meta name="viewport" content="width=device-width, initial-scale=1.0">
  <title>Document</title>
   <style>
      .container {
        text-align: center;
        margin-top: 50px;
      }
      body {
        width: 400px;
        background-color: #ffffff;
        font-family: Arial, sans-serif;
      border: 3px solid #000000;
      }
h1 {
  margin: 20px;
  text-align: center;
}
   </style>
</head>
<body>
  <h1> Requirement</h1>
  <div>
    <ol type="i">
      <li>System  with minimum i3 processer or better</li>
      <li>At least 4GB of RAM</li>
      <li>Working internet connection</li>
      <li>Dedication to learn</li>
    </ol>
  </div>
</body>
</html>
